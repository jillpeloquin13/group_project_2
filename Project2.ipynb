# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Create a path to use the csv 
ramen_csv_path = "Resources/ramen-ratings.csv"
happiness_2017_csv_path = "Resources/2017.csv"
happiness_2018_csv_path = "Resources/2018.csv"
happiness_2019_csv_path = "Resources/2019.csv"

# %%
# Read into Pandas DataFrame
ramen_data = pd.read_csv(ramen_csv_path)
happiness_2017_data = pd.read_csv(happiness_2017_csv_path)
happiness_2018_data = pd.read_csv(happiness_2018_csv_path)
happiness_2019_data = pd.read_csv(happiness_2019_csv_path)

# %%
# Show Ramen Data
ramen_data.head(35)
# Out:
#     Review #             Brand  \
# 0       2580         New Touch
# 1       2579          Just Way
# 2       2578            Nissin
# 3       2577           Wei Lih
# 4       2576    Ching's Secret
# 5       2575     Samyang Foods
# 6       2574           Acecook
# 7       2573       Ikeda Shoku
# 8       2572        Ripe'n'Dry
# 9       2571              KOKA
# 10      2570       Tao Kae Noi
# 11      2569          Yamachan
# 12      2568          Nongshim
# 13      2567            Nissin
# 14      2566            Nissin
# 15      2565              KOKA
# 16      2564              TRDP
# 17      2563          Yamachan
# 18      2562          Binh Tay
# 19      2561             Paldo
# 20      2560            Nissin
# 21      2559  Jackpot Teriyaki
# 22      2558              KOKA
# 23      2557          Yamachan
# 24      2556    Ching's Secret
# 25      2555     Samyang Foods
# 26      2554           Yum-Mie
# 27      2553            Nissin
# 28      2552           MyKuali
# ...

# %%
# Get Ramen column names
ramen_column_names = list(ramen_data)
ramen_column_names
# Out:
# ['Review #', 'Brand', 'Variety', 'Style', 'Country', 'Stars', 'Top Ten']

# %%
# Clean unnecessary columns
clean_ramen_data = ramen_data[['Brand', 'Variety', 'Style', 'Country', 'Stars']]
clean_ramen_data
# Out:
#                Brand                                            Variety Style  \
# 0          New Touch                          T's Restaurant Tantanmen    Cup
# 1           Just Way  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack
# 2             Nissin                      Cup Noodles Chicken Vegetable   Cup
# 3            Wei Lih                      GGE Ramen Snack Tomato Flavor  Pack
# 4     Ching's Secret                                    Singapore Curry  Pack
# ...              ...                                                ...   ...
# 2575           Vifon  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl
# 2576         Wai Wai                     Oriental Style Instant Noodles  Pack
# 2577         Wai Wai                                     Tom Yum Shrimp  Pack
# 2578         Wai Wai                               Tom Yum Chili Flavor  Pack
# 2579        Westbrae                                         Miso Ramen  Pack
#
#        Country Stars
# ...

# %%
# Show Happiness 2017
happiness_2017_data.head(35)
# Out:
#                      Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                     Norway               1            7.537      7.594445
# 1                    Denmark               2            7.522      7.581728
# 2                    Iceland               3            7.504      7.622030
# 3                Switzerland               4            7.494      7.561772
# 4                    Finland               5            7.469      7.527542
# 5                Netherlands               6            7.377      7.427426
# 6                     Canada               7            7.316      7.384403
# 7                New Zealand               8            7.314      7.379510
# 8                     Sweden               9            7.284      7.344095
# 9                  Australia              10            7.284      7.356651
# 10                    Israel              11            7.213      7.279853
# ...

# %%
# Show Happiness 2018
happiness_2018_data.head(35)
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 0              1               Finland  7.632           1.305           1.592
# 1              2                Norway  7.594           1.456           1.582
# 2              3               Denmark  7.555           1.351           1.590
# 3              4               Iceland  7.495           1.343           1.644
# 4              5           Switzerland  7.487           1.420           1.549
# 5              6           Netherlands  7.441           1.361           1.488
# 6              7                Canada  7.328           1.330           1.532
# 7              8           New Zealand  7.324           1.268           1.601
# 8              9                Sweden  7.314           1.355           1.501
# 9             10             Australia  7.272           1.340           1.573
# 10            11        United Kingdom  7.190           1.244           1.433
# ...

# %%
# Show Happiness 2019
happiness_2019_data.head(35)
# Out:
#     Overall rank     Country or region  Score  GDP per capita  Social support  \
# 0              1               Finland  7.769           1.340           1.587
# 1              2               Denmark  7.600           1.383           1.573
# 2              3                Norway  7.554           1.488           1.582
# 3              4               Iceland  7.494           1.380           1.624
# 4              5           Netherlands  7.488           1.396           1.522
# 5              6           Switzerland  7.480           1.452           1.526
# 6              7                Sweden  7.343           1.387           1.487
# 7              8           New Zealand  7.307           1.303           1.557
# 8              9                Canada  7.278           1.365           1.505
# 9             10               Austria  7.246           1.376           1.475
# 10            11             Australia  7.228           1.372           1.548
# ...

# %%
# Get Happiness 2017 column names
happiness_2017_column_names = list(happiness_2017_data)
happiness_2017_column_names
# Out:
# ['Country',
#  'Happiness.Rank',
#  'Happiness.Score',
#  'Whisker.high',
#  'Whisker.low',
#  'Economy..GDP.per.Capita.',
#  'Family',
#  'Health..Life.Expectancy.',
#  'Freedom',
#  'Generosity',
#  'Trust..Government.Corruption.',
#  'Dystopia.Residual']

# %%
# Get Happiness 2018 column names
happiness_2018_column_names = list(happiness_2018_data)
happiness_2018_column_names
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption']

# %%
# Get Happiness 2019 column names
happiness_2019_column_names = list(happiness_2019_data)
happiness_2019_column_names
# Out:
# ['Overall rank',
#  'Country or region',
#  'Score',
#  'GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption']

# %%
# Rename Happiness 2017 columns to match Happiness 2018 & Happiness 2019 column names
happiness_2017_data_renamed = happiness_2017_data.rename(columns={"Country" : "Country or region",
                                                                 "Happiness.Rank" : "Overall rank",
                                                                 "Happiness.Score" : "Score",
                                                                 "Health..Life.Expectancy." : "Healthy life expectancy",
                                                                 "Freedom" : "Freedom to make life choices",
                                                                 "Trust..Government.Corruption." : "Perceptions of corruption"})
happiness_2017_data_renamed.head()
# Out:
#   Country or region  Overall rank  Score  Whisker.high  Whisker.low  \
# 0            Norway             1  7.537      7.594445     7.479556
# 1           Denmark             2  7.522      7.581728     7.462272
# 2           Iceland             3  7.504      7.622030     7.385970
# 3       Switzerland             4  7.494      7.561772     7.426227
# 4           Finland             5  7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Healthy life expectancy  \
# 0                  1.616463  1.533524                 0.796667
# 1                  1.482383  1.551122                 0.792566
# 2                  1.480633  1.610574                 0.833552
# 3                  1.564980  1.516912                 0.858131
# 4                  1.443572  1.540247                 0.809158
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                      0.635423    0.362012                   0.315964
# ...

# %%
# Clean unnecessary columns
clean_happiness_2017 = happiness_2017_data_renamed[['Overall rank', 'Country or region', 'Score', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
clean_happiness_2017.head()
# Out:
#    Overall rank Country or region  Score  Healthy life expectancy  \
# 0             1            Norway  7.537                 0.796667
# 1             2           Denmark  7.522                 0.792566
# 2             3           Iceland  7.504                 0.833552
# 3             4       Switzerland  7.494                 0.858131
# 4             5           Finland  7.469                 0.809158
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                      0.635423    0.362012                   0.315964
# 1                      0.626007    0.355280                   0.400770
# 2                      0.627163    0.475540                   0.153527
# 3                      0.620071    0.290549                   0.367007
# 4                      0.617951    0.245483                   0.382612

# %%
# Clean unnecessary columns
clean_happiness_2018 = happiness_2018_data[['Overall rank', 'Country or region', 'Score', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
clean_happiness_2018.head()
# Out:
#    Overall rank Country or region  Score  Healthy life expectancy  \
# 0             1           Finland  7.632                    0.874
# 1             2            Norway  7.594                    0.861
# 2             3           Denmark  7.555                    0.868
# 3             4           Iceland  7.495                    0.914
# 4             5       Switzerland  7.487                    0.927
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.681       0.202                      0.393
# 1                         0.686       0.286                      0.340
# 2                         0.683       0.284                      0.408
# 3                         0.677       0.353                      0.138
# 4                         0.660       0.256                      0.357

# %%
# Clean unnecessary columns
clean_happiness_2019 = happiness_2019_data[['Overall rank', 'Country or region', 'Score', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]
clean_happiness_2019.head()
# Out:
#    Overall rank Country or region  Score  Healthy life expectancy  \
# 0             1           Finland  7.769                    0.986
# 1             2           Denmark  7.600                    0.996
# 2             3            Norway  7.554                    1.028
# 3             4           Iceland  7.494                    1.026
# 4             5       Netherlands  7.488                    0.999
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.596       0.153                      0.393
# 1                         0.592       0.252                      0.410
# 2                         0.603       0.271                      0.341
# 3                         0.591       0.354                      0.118
# 4                         0.557       0.322                      0.298
